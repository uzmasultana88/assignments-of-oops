# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
#
# Ans. customize the exception according to user need. Consider an example int("str") in which typeerror class extends the Exception class if in try block type error is present .if not then we should have at the end exception base class so according to the error  that  exception class gets executed
# . Using the custom exception, we can have your own exception and message.

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
# import inspect module
import inspect
  
def treeClass(cls, ind = 0):
    
    print ('-' * ind, cls.__name__)
      
    # iterating through subclasses
    for i in cls.__subclasses__():
        treeClass(i, ind + 3)
  
print("Hierarchy for Built-in exceptions is : ")
  
# inspect.getmro() Return a tuple 
# of class  cls’s base classes.
  
# building a tree hierarchy 
inspect.getclasstree(inspect.getmro(BaseException))
  
# function call
treeClass(BaseException)
# Out:
# Hierarchy for Built-in exceptions is :
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- itimer_error
# --------- herror
# --------- gaierror
# --------- SSLError
# ------------ SSLCertVerificationError
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.
#
#
# Ans.------ ArithmeticError
# --------- FloatingPointError
# --------- OverflowError
# --------- ZeroDivisionError
# ------------ DivisionByZero
# ------------ DivisionUndefined
# --------- DecimalException
# ------------ Clamped
# ------------ Rounded
# --------------- Underflow
# --------------- Overflow
# ------------ Inexact
# --------------- Underflow
# --------------- Overflow
# ------------ Subnormal
# --------------- Underflow
# ------------ DivisionByZero
# ------------ FloatOperation
# ------------ InvalidOperation
# --------------- ConversionSyntax
# --------------- DivisionImpossible
# --------------- DivisionUndefined
#
# these error comes under arithematic error

# %%
try:
    1/0
except ArithmeticError as e:
    print(f"{e}, {e.__class__}")
# Out:
# division by zero, <class 'ZeroDivisionError'>

# %%
j = 5.0

try:
    for i in range(1, 1000):
        j = j**i
except ArithmeticError as e:
    print(f"{e}, {e.__class__}")
# Out:
# (34, 'Numerical result out of range'), <class 'OverflowError'>

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# LookupError Exception is the Base class for errors raised when something can't be found. The base class for the exceptions that are raised when a key or index used on a mapping or sequence is invalid: IndexError, KeyError. An IndexError is raised when a sequence reference is out of range

# %%
try:
    l=[1,2,3]
    l[10]
except IndexError as e:
    print("selected index is not in range",e)
# Out:
# selected index is not in range list index out of range

# %%
try :
    d = {"key1": [3,4,5,6] , "key2" :"uzma"}
    d["key3"]
except KeyError as e : 
    print("dictionary key is not present in dict",e)
# Out:
# dictionary key is not present in dict 'key3'

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# Python's ImportError ( ModuleNotFoundError ) indicates that you tried to import a module that Python doesn't find. It can usually be eliminated by adding a file named __init__.py to the directory and then adding this directory to $PYTHONPATH .

# %%
try:
    import uzma
except ImportError as e:
    print("there is no module found with this name ",e)
# Out:
# there is no module found with this name  No module named 'uzma'

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %% [markdown]
# #use always a specific exception
#
# #print always a valid message so that  during debug they can understand what is exact error
#
# #always try to log
#
# #always avoid to  write  multiple exception handling
#
# #always prepare a proper documentation
